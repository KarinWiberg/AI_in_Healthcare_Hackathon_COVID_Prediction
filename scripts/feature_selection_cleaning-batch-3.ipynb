# %% [markdown]
# # Feature Selection & Cleaning
# Data-batch 3 of 3.

# %% [markdown]
# ## Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sb
import warnings

# %matplotlib inline

color = sb.color_palette("Set2")[0]
palette = sb.color_palette("Set2")

# %%
file_path = '../data/01.csv'
data21 = pd.read_csv(file_path, sep=';', encoding = 'ISO-8859-1')
data21.head()
# Out:
#    PATIENT ID  EDAD/AGE SEXO/SEX      DIAG ING/INPAT  \
# 0         577        78     MALE  COVID19 - POSITIVO
# 1          44        75   FEMALE  COVID19 - POSITIVO
# 2         585        62   FEMALE  COVID19 - POSITIVO
# 3         587        69     MALE  COVID19 - POSITIVO
# 4         586        67   FEMALE  COVID19 - POSITIVO
#
#   F_INGRESO/ADMISSION_D_ING/INPAT F_ENTRADA_UC/ICU_DATE_IN  \
# 0                      26/12/2019         26/12/2019 17:12
# 1                      28/01/2020         30/01/2020 13:03
# 2                      05/02/2020         10/03/2020 14:20
# 3                      06/02/2020                      NaN
# 4                      06/02/2020                      NaN
#
#   F_SALIDA_UCI/ICU_DATE_OUT  UCI_DIAS/ICU_DAYS F_ALTA/DISCHARGE_DATE_ING  \
# 0          27/12/2019 12:22                1.0                02/04/2020
# 1          31/01/2020 17:08                1.0                04/04/2020
# 2          20/03/2020 14:11               10.0                26/03/2020
# 3                       NaN                NaN                24/03/2020
# 4                       NaN                NaN                28/03/2020
#
#   MOTIVO_ALTA/DESTINY_DISCHARGE_ING  ... SAT_02_PRIMERA/FIRST_URG/EMERG  \
# 0                         Domicilio  ...                              0
# 1                         Domicilio  ...                              0
# 2                         Domicilio  ...                             97
# 3                         Domicilio  ...                             95
# 4                     Fallecimiento  ...                             93
#
#   TA_MAX_PRIMERA/FIRST/EMERG_URG TA_MIN_PRIMERA/FIRST_URG/EMERG  \
# 0                              0                              0
# 1                              0                              0
# 2                            160                            101
# 3                            141                             83
# 4                            151                             82
#
#   HORA/TIME_CONSTANT_ULTIMA/LAST_URG/EMERG FC/HR_ULTIMA/LAST_URG/EMERG  \
# 0                                      NaN                           0
# 1                                      NaN                           0
# 2                                 18:34:00                         105
# 3                                 18:54:00                          92
# 4                                  0:55:00                          84
#
#   TEMP_ULTIMA/LAST_URG/EMERG GLU_ULTIMA/LAST_URG/EMERG  \
# 0                          0                         0
# 1                          0                         0
# 2                          0                         0
# 3                         37                         0
# 4                         36                         0
#
#    SAT_02_ULTIMA/LAST_URG/EMERG  TA_MAX_ULTIMA/LAST_URGEMERG  \
# 0                             0                            0
# 1                             0                            0
# 2                            97                          160
# 3                            95                          141
# 4                            93                          151
#
#    TA_MIN_ULTIMA/LAST_URG/EMERG
# 0                             0
# 1                             0
# 2                           101
# 3                            83
# 4                            82
#
# [5 rows x 29 columns]

# %%
data21.rename(columns={'PATIENT ID': 'IDINGRESO',
                      'EDAD/AGE': 'EDAD',
                      'SEXO/SEX': 'SEX',
                      'MOTIVO_ALTA/DESTINY_DISCHARGE_ING': 'MOTIVO_ALTA_ING',
                      'TA_MAX_PRIMERA/FIRST/EMERG_URG': 'TA_MAX_PRIMERA_URG',
                      'TA_MIN_PRIMERA/FIRST_URG/EMERG': 'TA_MIN_PRIMERA_URG',
                      'TEMP_PRIMERA/FIRST_URG/EMERG': 'TEMP_PRIMERA_URG',
                      'FC/HR_PRIMERA/FIRST_URG/EMERG': 'FC_PRIMERA_URG',
                      'SAT_02_PRIMERA/FIRST_URG/EMERG': 'SAT_02_PRIMERA_URG',
                      'GLU_PRIMERA/FIRST_URG/EMERG': 'GLU_PRIMERA_URG',
                      'UCI_DIAS/ICU_DAYS': 'UCI_DAYS'}, inplace=True)

# %%
data21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2307 entries, 0 to 2306
# Data columns (total 29 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   IDINGRESO                                   2307 non-null   int64
#  1   EDAD                                        2307 non-null   int64
#  2   SEX                                         2307 non-null   object
#  3   DIAG ING/INPAT                              2307 non-null   object
#  4   F_INGRESO/ADMISSION_D_ING/INPAT             2307 non-null   object
#  5   F_ENTRADA_UC/ICU_DATE_IN                    219 non-null    object
#  6   F_SALIDA_UCI/ICU_DATE_OUT                   201 non-null    object
#  7   UCI_DAYS                                    201 non-null    float64
#  8   F_ALTA/DISCHARGE_DATE_ING                   2089 non-null   object
#  9   MOTIVO_ALTA_ING                             2048 non-null   object
#  10  F_INGRESO/ADMISSION_DATE_URG/EMERG          2224 non-null   object
#  11  HORA/TIME_ADMISION/ADMISSION_URG/EMERG      2224 non-null   object
#  12  ESPECIALIDAD/DEPARTMENT_URG/EMERG           2224 non-null   object
#  13  DIAG_URG/EMERG                              2224 non-null   object
#  14  DESTINO/DESTINY_URG/EMERG                   2224 non-null   object
#  15  HORA/TIME_CONSTANT_PRIMERA/FIRST_URG/EMERG  1850 non-null   object
#  16  TEMP_PRIMERA_URG                            2307 non-null   object
#  17  FC_PRIMERA_URG                              2307 non-null   int64
#  18  GLU_PRIMERA_URG                             2307 non-null   int64
#  19  SAT_02_PRIMERA_URG                          2307 non-null   int64
#  20  TA_MAX_PRIMERA_URG                          2307 non-null   int64
#  21  TA_MIN_PRIMERA_URG                          2307 non-null   int64
#  22  HORA/TIME_CONSTANT_ULTIMA/LAST_URG/EMERG    2224 non-null   object
#  23  FC/HR_ULTIMA/LAST_URG/EMERG                 2307 non-null   int64
#  24  TEMP_ULTIMA/LAST_URG/EMERG                  2307 non-null   object
#  25  GLU_ULTIMA/LAST_URG/EMERG                   2307 non-null   int64
#  26  SAT_02_ULTIMA/LAST_URG/EMERG                2307 non-null   int64
#  27  TA_MAX_ULTIMA/LAST_URGEMERG                 2307 non-null   int64
#  28  TA_MIN_ULTIMA/LAST_URG/EMERG                2307 non-null   int64
# dtypes: float64(1), int64(12), object(16)
# memory usage: 522.8+ KB

# %%
# Lab table
warnings.simplefilter('ignore')
file_path = '../data/04.csv'
data24 = pd.read_csv(file_path, sep=';', encoding = 'ISO-8859-1', error_bad_lines = False)
data24.head()
# Out:
# 2                  00:00                                  MONO -- Monocitos
# 3                  00:00                                   BAS -- Basófilos
# 4                  00:00  BT -- BILIRRUBINA TOTAL                       ...
#
#   RESULTADO/VAL_RESULT UNIDADES/UD_RESULT VALORES_REFERENCIA/REF_VALUES
# 0                215.0                U/L                           <41
# 1                  3.0                  %                 (20.0 - 50.0)
# 2                 0.12           x10e3/µL                   (0.1 - 0.8)
# 3                 0.02           x10e3/µL                   (0.0 - 0.3)
# 4                 0.43              mg/dL                          <1.2

# %%
data24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395858 entries, 0 to 395857
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   IDINGRESO   395858 non-null  int64
#  1   LAB_NUMBER  395858 non-null  object
#  2   LAB_DATE    395858 non-null  object
#  3   TIME_LAB    395858 non-null  object
#  4   ITEM_LAB    395858 non-null  object
#  5   VAL_RESULT  395851 non-null  object
#  6   UD_RESULT   373464 non-null  object
#  7   REF_VALUES  386679 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 24.2+ MB

# %%
data24.rename(columns={'PATIENT ID': 'IDINGRESO',
                      'PETICION_LABORATORIO/LAB_NUMBER': 'LAB_NUMBER',
                      'FECHA_PETICION/LAB_DATE': 'LAB_DATE',
                      'HORA_PETICION/TIME_LAB': 'TIME_LAB',
                      'DETERMINACION/ITEM_LAB': 'ITEM_LAB',
                      'RESULTADO/VAL_RESULT': 'VAL_RESULT',
                      'UNIDADES/UD_RESULT': 'UD_RESULT',
                      'VALORES_REFERENCIA/REF_VALUES': 'REF_VALUES'}, inplace=True)

# %% [markdown]
# ## Cleaning
# Table 1 = Main
# - Remove the patient who escaped from the hospital and reindex
# - Create categorical variabel of "Mortivo_alta" column: "Recovery", "Recovery in Progress", "Death"
#
# Table 6 = Labworks
# - Pivot pressumed important lab tests
#
# Combination table
# - Combine the main table & the pivoted labworks

# %%
# Always clean of copied df
main = data21.copy()
labworks = data24.copy()

# %%
# Remove the one patient who escaped from the hospital from main
# drop_idx = main[main.MOTIVO_ALTA_ING == 'Fuga'].index[0]
# main.drop(index = drop_idx, axis=0, inplace=True)

# %%
# Test removal
# sum(main[main.index == drop_idx].index == drop_idx)

# %%
# Reset index main
main.reset_index(inplace=True)

# %%
# Pivot labworks
tests = ['PLAQ -- SISTEMATICO DE SANGRE', 'PCR -- PROTEINA C REACTIVA', 'CREA -- CREATININA', 'LIN -- SISTEMATICO DE SANGRE', 'DD -- DIMERO D']
labworks_ed = labworks[labworks.ITEM_LAB.isin(tests)]
labworks_ed
# Out:
#         IDINGRESO LAB_NUMBER    LAB_DATE TIME_LAB                    ITEM_LAB  \
# 33             13       I-12  31-03-2020    00:00  PCR -- PROTEINA C REACTIVA
# 39             13       I-14  30-03-2020    00:00  PCR -- PROTEINA C REACTIVA
# 134            13        I-7  29-03-2020    00:00          CREA -- CREATININA
# 137            13        I-7  29-03-2020    00:00  PCR -- PROTEINA C REACTIVA
# 171            14       I-13  25-03-2020    00:00  PCR -- PROTEINA C REACTIVA
# ...           ...        ...         ...      ...                         ...
# 395751       2278        I-1  13-04-2020    00:00          CREA -- CREATININA
# 395758       2279        I-1  12-04-2020    00:00              DD -- DIMERO D
# 395774       2282        U-1  11-04-2020    23:58              DD -- DIMERO D
# 395849       2288        U-1  11-04-2020    12:38              DD -- DIMERO D
# 395854       2289        I-1  13-04-2020    00:00              DD -- DIMERO D
#
#        VAL_RESULT UD_RESULT   REF_VALUES
# 33          63.54      mg/L           <5
# 39          28.99      mg/L           <5
# 134          0.56     mg/dL  (0.7 - 1.2)
# 137         18.16      mg/L           <5
# 171          6.85      mg/L           <5
# ...           ...       ...          ...
# 395751       1.28     mg/dL  (0.7 - 1.2)
# 395758     2044.0     ng/mL        <500^
# 395774    74803.0     ng/mL        <500^
# 395849      828.0     ng/mL        <500^
# 395854      452.0     ng/mL        <500^
#
# [23598 rows x 8 columns]

# %%
labworks_ed.ITEM_LAB.unique()
# Out:
# array(['PCR -- PROTEINA C REACTIVA', 'CREA -- CREATININA',
#        'DD -- DIMERO D'], dtype=object)

# %% [markdown]
# ### Feature Reduction

# %%
main.head()
# Out:
#    index  IDINGRESO  EDAD     SEX      DIAG ING/INPAT  \
# 0      0        577    78    MALE  COVID19 - POSITIVO
# 1      1         44    75  FEMALE  COVID19 - POSITIVO
# 2      2        585    62  FEMALE  COVID19 - POSITIVO
# 3      3        587    69    MALE  COVID19 - POSITIVO
# 4      4        586    67  FEMALE  COVID19 - POSITIVO
#
#   F_INGRESO/ADMISSION_D_ING/INPAT F_ENTRADA_UC/ICU_DATE_IN  \
# 0                      26/12/2019         26/12/2019 17:12
# 1                      28/01/2020         30/01/2020 13:03
# 2                      05/02/2020         10/03/2020 14:20
# 3                      06/02/2020                      NaN
# 4                      06/02/2020                      NaN
#
#   F_SALIDA_UCI/ICU_DATE_OUT  UCI_DAYS F_ALTA/DISCHARGE_DATE_ING  ...  \
# 0          27/12/2019 12:22       1.0                02/04/2020  ...
# 1          31/01/2020 17:08       1.0                04/04/2020  ...
# 2          20/03/2020 14:11      10.0                26/03/2020  ...
# 3                       NaN       NaN                24/03/2020  ...
# 4                       NaN       NaN                28/03/2020  ...
#
#   SAT_02_PRIMERA_URG TA_MAX_PRIMERA_URG TA_MIN_PRIMERA_URG  \
# 0                  0                  0                  0
# 1                  0                  0                  0
# 2                 97                160                101
# 3                 95                141                 83
# 4                 93                151                 82
#
#   HORA/TIME_CONSTANT_ULTIMA/LAST_URG/EMERG FC/HR_ULTIMA/LAST_URG/EMERG  \
# 0                                      NaN                           0
# 1                                      NaN                           0
# 2                                 18:34:00                         105
# 3                                 18:54:00                          92
# 4                                  0:55:00                          84
#
#   TEMP_ULTIMA/LAST_URG/EMERG GLU_ULTIMA/LAST_URG/EMERG  \
# 0                          0                         0
# 1                          0                         0
# 2                          0                         0
# 3                         37                         0
# 4                         36                         0
#
#   SAT_02_ULTIMA/LAST_URG/EMERG  TA_MAX_ULTIMA/LAST_URGEMERG  \
# 0                            0                            0
# 1                            0                            0
# 2                           97                          160
# 3                           95                          141
# 4                           93                          151
#
#    TA_MIN_ULTIMA/LAST_URG/EMERG
# 0                             0
# 1                             0
# 2                           101
# 3                            83
# 4                            82
#
# [5 rows x 30 columns]

# %%
# Main
keep_list = ['EDAD', 'SEX', 'IDINGRESO',
             'TA_MAX_PRIMERA_URG', 'TA_MIN_PRIMERA_URG',
             'TEMP_PRIMERA_URG', 'FC_PRIMERA_URG', 'SAT_02_PRIMERA_URG',
             'GLU_PRIMERA_URG', 'MOTIVO_ALTA_ING', 
             'UCI_DAYS']

main_ed = main[keep_list] # keep the listed columns

# %%
# Change dtypes
main_ed.IDINGRESO = main_ed.IDINGRESO.astype('str')

# %%
'''
# Replace commas with dots
for idx, val in enumerate(main_ed.TEMP_PRIMERA_URG):
    #print(idx, val)
    #print(labworks_ed.ITEM_LAB.iloc[idx])
    main_ed.TEMP_PRIMERA_URG.iloc[idx] = main_ed.TEMP_PRIMERA_URG.iloc[idx].replace(',', '.')
    #print(labworks_ed.ITEM_LAB.iloc[idx])
    
main_ed.TEMP_PRIMERA_URG

# Change dtype from object to float
main_ed.TEMP_PRIMERA_URG = main_ed.TEMP_PRIMERA_URG.astype(float)
'''
# Out:
# "\n# Replace commas with dots\nfor idx, val in enumerate(main_ed.TEMP_PRIMERA_URG):\n    #print(idx, val)\n    #print(labworks_ed.ITEM_LAB.iloc[idx])\n    main_ed.TEMP_PRIMERA_URG.iloc[idx] = main_ed.TEMP_PRIMERA_URG.iloc[idx].replace(',', '.')\n    #print(labworks_ed.ITEM_LAB.iloc[idx])\n    \nmain_ed.TEMP_PRIMERA_URG\n\n# Change dtype from object to float\nmain_ed.TEMP_PRIMERA_URG = main_ed.TEMP_PRIMERA_URG.astype(float)\n"

# %%
# Labworks_ed
labworks_ed.ITEM_LAB.unique()
# Out:
# array(['PCR -- PROTEINA C REACTIVA', 'CREA -- CREATININA',
#        'DD -- DIMERO D'], dtype=object)

# %%
# Labworks_ed
print(f'Shape before: {labworks.shape}')

drop_list = ['LAB_NUMBER', 'LAB_DATE', 'TIME_LAB', 'UD_RESULT', 'REF_VALUES']
labworks_ed.drop(drop_list, axis=1, inplace=True)
labworks_ed.reset_index(inplace=True)
print(f'Shape after: {labworks_ed.shape}')
# Out:
# Shape before: (395858, 8)
# Shape after: (23598, 4)

# %%
lab_tests = list(labworks_ed.ITEM_LAB.unique())
lab_tests
# Out:
# ['PCR -- PROTEINA C REACTIVA', 'CREA -- CREATININA', 'DD -- DIMERO D']

# %%
# Change ID to str = Unique
labworks_ed.IDINGRESO = labworks_ed.IDINGRESO.astype('str')

# Change VAL_RESULT to float
labworks_ed.VAL_RESULT = pd.to_numeric(labworks_ed.VAL_RESULT, errors='coerce')

# %%
# Remove blank spaces before pivoting
for idx, val in enumerate(labworks_ed.ITEM_LAB):
    #print(idx, val)
    #print(labworks_ed.ITEM_LAB.iloc[idx])
    labworks_ed.ITEM_LAB.iloc[idx] = labworks_ed.ITEM_LAB.iloc[idx].replace(' ', '')
    #print(labworks_ed.ITEM_LAB.iloc[idx])
    
labworks_ed.ITEM_LAB
# Out:
# 0        PCR--PROTEINACREACTIVA
# 1        PCR--PROTEINACREACTIVA
# 2              CREA--CREATININA
# 3        PCR--PROTEINACREACTIVA
# 4        PCR--PROTEINACREACTIVA
#                   ...
# 23593          CREA--CREATININA
# 23594               DD--DIMEROD
# 23595               DD--DIMEROD
# 23596               DD--DIMEROD
# 23597               DD--DIMEROD
# Name: ITEM_LAB, Length: 23598, dtype: object

# %%
# Pivot labworks
labworks_piv = labworks_ed.pivot_table(index = 'IDINGRESO', columns = 'ITEM_LAB', values = 'VAL_RESULT')
labworks_piv
# Out:
# ITEM_LAB   CREA--CREATININA   DD--DIMEROD  PCR--PROTEINACREACTIVA
# IDINGRESO
# 1                  1.460000  25131.000000              359.405000
# 100                0.857500  23514.857143               63.411364
# 1001               1.890000    917.500000              107.390000
# 1002               0.615000   2998.000000              146.025000
# 1003               1.060000   1209.000000              117.053333
# ...                     ...           ...                     ...
# 995                0.630000           NaN               22.730000
# 996                1.616667   2334.333333              155.440000
# 997                0.640000    462.000000               94.075000
# 998                0.890000   3593.500000               40.925000
# 999                0.792500    463.250000               76.420000
#
# [2049 rows x 3 columns]

# %% [markdown]
# ### Feature Engineering

# %%
# Insert new categorical column
main_ed.insert(loc = 6, column = 'PATIENT_OUTCOME', value = 'null')

# %%
for idx, val in enumerate(main.MOTIVO_ALTA_ING):
    #print(idx, val)
    
    if val == 'Domicilio': # Domicilio
        main_ed.PATIENT_OUTCOME[idx] = 'RECOVERED'
    
    elif val == 'Fallecimiento':
        main_ed.PATIENT_OUTCOME[idx] = 'DEATH'
        
    else:
        main_ed.PATIENT_OUTCOME[idx] = 'RECOVERY_IN_PROGRESS'

main_ed.PATIENT_OUTCOME
# Out:
# 0                  RECOVERED
# 1                  RECOVERED
# 2                  RECOVERED
# 3                  RECOVERED
# 4                      DEATH
#                 ...
# 2302    RECOVERY_IN_PROGRESS
# 2303               RECOVERED
# 2304    RECOVERY_IN_PROGRESS
# 2305               RECOVERED
# 2306               RECOVERED
# Name: PATIENT_OUTCOME, Length: 2307, dtype: object

# %%
main_ed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2307 entries, 0 to 2306
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EDAD                2307 non-null   int64
#  1   SEX                 2307 non-null   object
#  2   IDINGRESO           2307 non-null   object
#  3   TA_MAX_PRIMERA_URG  2307 non-null   int64
#  4   TA_MIN_PRIMERA_URG  2307 non-null   int64
#  5   TEMP_PRIMERA_URG    2307 non-null   object
#  6   PATIENT_OUTCOME     2307 non-null   object
#  7   FC_PRIMERA_URG      2307 non-null   int64
#  8   SAT_02_PRIMERA_URG  2307 non-null   int64
#  9   GLU_PRIMERA_URG     2307 non-null   int64
#  10  MOTIVO_ALTA_ING     2048 non-null   object
#  11  UCI_DAYS            201 non-null    float64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 216.4+ KB

# %%
# Remove the last columns
main_ed = main_ed.drop('MOTIVO_ALTA_ING', axis = 1)

# %% [markdown]
# ## Combine Tables

# %%
main_ed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2307 entries, 0 to 2306
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EDAD                2307 non-null   int64
#  1   SEX                 2307 non-null   object
#  2   IDINGRESO           2307 non-null   object
#  3   TA_MAX_PRIMERA_URG  2307 non-null   int64
#  4   TA_MIN_PRIMERA_URG  2307 non-null   int64
#  5   TEMP_PRIMERA_URG    2307 non-null   object
#  6   PATIENT_OUTCOME     2307 non-null   object
#  7   FC_PRIMERA_URG      2307 non-null   int64
#  8   SAT_02_PRIMERA_URG  2307 non-null   int64
#  9   GLU_PRIMERA_URG     2307 non-null   int64
#  10  UCI_DAYS            201 non-null    float64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 198.4+ KB

# %%
labworks_piv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2049 entries, 1 to 999
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CREA--CREATININA        2030 non-null   float64
#  1   DD--DIMEROD             1859 non-null   float64
#  2   PCR--PROTEINACREACTIVA  2026 non-null   float64
# dtypes: float64(3)
# memory usage: 64.0+ KB

# %%
data = main_ed.merge(labworks_piv, on = 'IDINGRESO')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2048 entries, 0 to 2047
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   EDAD                    2048 non-null   int64
#  1   SEX                     2048 non-null   object
#  2   IDINGRESO               2048 non-null   object
#  3   TA_MAX_PRIMERA_URG      2048 non-null   int64
#  4   TA_MIN_PRIMERA_URG      2048 non-null   int64
#  5   TEMP_PRIMERA_URG        2048 non-null   object
#  6   PATIENT_OUTCOME         2048 non-null   object
#  7   FC_PRIMERA_URG          2048 non-null   int64
#  8   SAT_02_PRIMERA_URG      2048 non-null   int64
#  9   GLU_PRIMERA_URG         2048 non-null   int64
#  10  UCI_DAYS                175 non-null    float64
#  11  CREA--CREATININA        2029 non-null   float64
#  12  DD--DIMEROD             1858 non-null   float64
#  13  PCR--PROTEINACREACTIVA  2025 non-null   float64
# dtypes: float64(4), int64(6), object(4)
# memory usage: 240.0+ KB

# %%
data.head()
# Out:
#    EDAD     SEX IDINGRESO  TA_MAX_PRIMERA_URG  TA_MIN_PRIMERA_URG  \
# 0    78    MALE       577                   0                   0
# 1    75  FEMALE        44                   0                   0
# 2    62  FEMALE       585                 160                 101
# 3    69    MALE       587                 141                  83
# 4    67  FEMALE       586                 151                  82
#
#   TEMP_PRIMERA_URG PATIENT_OUTCOME  FC_PRIMERA_URG  SAT_02_PRIMERA_URG  \
# 0                0       RECOVERED               0                   0
# 1                0       RECOVERED               0                   0
# 2                0       RECOVERED             105                  97
# 3      37,09999847       RECOVERED              92                  95
# 4               36           DEATH              84                  93
#
#    GLU_PRIMERA_URG  UCI_DAYS  CREA--CREATININA  DD--DIMEROD  \
# 0                0       1.0          0.773544  2009.000000
# 1                0       1.0          1.001282   810.166667
# 2                0      10.0          0.434615  1346.000000
# 3                0       NaN          0.567333  1309.000000
# 4                0       NaN          0.370000  3097.666667
#
#    PCR--PROTEINACREACTIVA
# 0              122.891268
# 1               54.410800
# 2               76.676316
# 3               38.168571
# 4               53.270000

# %% [markdown]
# ### One-Hot Encoding

# %%
# Sex
data[['FEMALE', 'MALE']] = pd.get_dummies(data.SEX)

# %%
sorted(list(data.PATIENT_OUTCOME.unique()))
# Out:
# ['DEATH', 'RECOVERED', 'RECOVERY_IN_PROGRESS']

# %%
# PATIENT_OUTCOME
sorted_list = sorted(list(data.PATIENT_OUTCOME.unique()))
data[sorted_list]=pd.get_dummies(data.PATIENT_OUTCOME)

# %%
# Remove the orgiginal columns
data = data.drop(['SEX', 'PATIENT_OUTCOME'], axis=1)

# %% [markdown]
# ## Save Cleaned Data

# %%
# Saving data batch 1

path = 'data/'
file_name = 'cleaned_data_v1-3.csv'
file_path = path + file_name
data.to_csv(file_path)
