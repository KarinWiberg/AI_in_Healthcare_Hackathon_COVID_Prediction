# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %matplotlib inline

# %% [markdown]
# # Gather Data
#
# The data is collected in three blocks:
# - 2021-04-19 _COVID_DSL_0X.CSV_
# - 2020-07-20 _CDSL_0X.csv_
# - 2020-04-24 _0X.csv_
#
# Each block containing 6 different tables/.cdv-files.
#
# ### Data Description
# - The main table includes data on the admission and the patient (age and sex), data on the previous emergency if there has been one (2,226 records), data on their stay in the ICU if there has been one and records of the first and last set of emergency constants.
# - The medication table shows all the medication administered to each patient during admission (more than 60,000 records), with the dates corresponding to the first and last administration of each drug, identified by their brand name and classification in the ATC5/ATC7.
# - In the table of vital signs, there are all the basic records of constants (54,000 records so far) collected during admission with their date and time of registration.
# - The laboratory table contains the results of the determinations (398,884 records) of all the requests made to each patient during admission and in the previous emergency, if any.
# - And finally, the ICD10 coding tables show the records of diagnostic and procedural information coded according to the international ICD10 classification in its latest distributed version (does not include COVID), for the patients referred, both for episodes of hospital admission (more than 1,600) and for the emergency (more than 1,900) prior to those episodes, if any.
#
# ### Data Specification
# 1. **Records of Inpatients:** demographic, data on the episode of admission, data on the previous emergency episode, if any, data on the ICU, if there has been.
# 2. **Records of medication** prescribed and administered during admission (ICU medication is not collected).
# 3. **Records of constants** during admission (ICU records are not collected).
# 4. **Records of the results of laboratory requests** made during admission and in the previous emergency, if there have been.
# 5. **Records of the emergency coding**, if any, according to the ICD10.
# 6. **Records for inpatient coding** according to ICD10.
#
# Translation of the headlines in each file from spanish to english is covered in the file _COVID_DATA_SAVE_LIVES_.

# %%
s = os.path.dirname(os.getcwd()).rstrip()
s = s[1:]

# %%
os.listdir()
# Out:
# ['cleaning.ipynb',
#  '.DS_Store',
#  'utils',
#  'README.md',
#  '.ipynb_checkpoints',
#  '.git',
#  'data']

# %%
pd.read_csv('data/COVID_DSL_01.CSV', sep='|', encoding = 'ISO-8859-1')
# Out:
#       EDAD     SEX  IDINGRESO        F_INGRESO_ING           F_ALTA_ING  \
# 0       55    MALE        508  2020-04-05 00:00:00  2020-04-15 00:00:00
# 1       54    MALE        509  2020-04-05 00:00:00  2020-04-14 00:00:00
# 2       73    MALE        510  2020-04-05 00:00:00  2020-04-20 00:00:00
# 3       90  FEMALE        511  2020-04-06 00:00:00  2020-04-07 00:00:00
# 4       70  FEMALE        512  2020-04-06 00:00:00  2020-04-28 00:00:00
# ...    ...     ...        ...                  ...                  ...
# 4474    61    MALE       2742  2020-03-22 00:00:00  2020-03-24 00:00:00
# 4475    54    MALE       2743  2020-03-22 00:00:00  2020-04-02 00:00:00
# 4476    77    MALE       2744  2020-03-23 00:00:00  2020-04-07 00:00:00
# 4477    71    MALE       2745  2020-03-22 00:00:00  2020-05-22 00:00:00
# 4478    62    MALE       2746  2020-03-23 00:00:00  2020-03-30 00:00:00
#
#            MOTIVO_ALTA_ING   DIAGNOSTICO_ING F_INGRESO_URG HORA_URG  \
# 0                Domicilio  COVID CONFIRMADO    05/04/2020    22:28
# 1                Domicilio  COVID CONFIRMADO    05/04/2020    22:32
# 2                Domicilio  COVID CONFIRMADO    05/04/2020    22:35
# 3                Domicilio    COVID SOSPECHA    05/04/2020    23:46
# 4     Traslado al Hospital  COVID CONFIRMADO    06/04/2020    00:57
# ...                    ...               ...           ...      ...
# 4474  Traslado al Hospital  COVID CONFIRMADO    22/03/2020    20:04
# 4475             Domicilio  COVID CONFIRMADO    22/03/2020    20:17
# 4476             Domicilio  COVID CONFIRMADO    22/03/2020    20:39
# 4477             Domicilio  COVID CONFIRMADO    22/03/2020    20:50
# 4478             Domicilio  COVID CONFIRMADO    22/03/2020    20:54
#
#                      DIAG_URG  ... GLU_ULTIMA_URG DESTINO_URG  IDCDSL  \
# 0     DIFICULTAD RESPIRATORIA  ...              0     Ingreso     508
# 1     DIFICULTAD RESPIRATORIA  ...              0     Ingreso     509
# 2     DIFICULTAD RESPIRATORIA  ...              0     Ingreso     510
# 3     DIFICULTAD RESPIRATORIA  ...              0     Ingreso     511
# 4     DIFICULTAD RESPIRATORIA  ...              0     Ingreso     512
# ...                       ...  ...            ...         ...     ...
# 4474                   FIEBRE  ...              0     Ingreso    2742
# 4475                      TOS  ...              0     Ingreso    2743
# 4476                      TOS  ...              0     Ingreso    2744
# 4477  DIFICULTAD RESPIRATORIA  ...              0     Ingreso    2745
# 4478                      TOS  ...              0     Ingreso    2746
#
#        F_ING_ANT            DIAG_ANT  RESPIRADOR  \
# 0            NaN                 NaN          SI
# 1            NaN                 NaN         NaN
# 2            NaN                 NaN          SI
# 3            NaN                 NaN         NaN
# 4            NaN                 NaN          SI
# ...          ...                 ...         ...
# 4474  2020-03-24    COVID CONFIRMADO          SI
# 4475         NaN                 NaN          SI
# 4476  2020-04-10  NEUTROPENIA FEBRIL          SI
# 4477  2020-07-09                 AIT          SI
# 4478         NaN                 NaN          SI
#
#                            F_UCI_IN                      F_UCI_OUT  UCI_DAYS  \
# 0                               NaN                            NaN       NaN
# 1                               NaN                            NaN       NaN
# 2                               NaN                            NaN       NaN
# 3                               NaN                            NaN       NaN
# 4                               NaN                            NaN       NaN
# ...                             ...                            ...       ...
# 4474                            NaN                            NaN       NaN
# 4475                            NaN                            NaN       NaN
# 4476                            NaN                            NaN       NaN
# 4477  2020-03-27 19:06:27.673000000  2020-04-27 13:32:57.683000000      31.0
# 4478                            NaN                            NaN       NaN
#
#      UCI_N_ING
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 4474       NaN
# 4475       NaN
# 4476       NaN
# 4477       4.0
# 4478       NaN
#
# [4479 rows x 35 columns]

# %%
pd.read_csv('data/COVID_DSL_02.CSV', sep='|', encoding = 'ISO-8859-1', low_memory = False)
# Out:
#         IDINGRESO CONSTANTS_ING_DATE CONSTANTS_ING_TIME  TA_MAX_ING  \
# 0            1843         2021-01-23              00:28           0
# 1            1764         2021-01-23              00:31           0
# 2            1761         2021-01-23              00:32           0
# 3            1792         2021-01-23              00:32           0
# 4            1225         2021-01-23              00:32           0
# ...           ...                ...                ...         ...
# 224141        542         2020-05-17              10:27           0
# 224142        605         2020-05-17              11:55           0
# 224143        580         2020-11-08              15:46           0
# 224144       4298         2020-11-08              15:50           0
# 224145       4282         2020-11-08              15:52           0
#
#         TA_MIN_ING TEMP_ING  FC_HR_ING  SAT_02_ING    SAT_02_ING_OBS  \
# 0                0        0          0          95       SATO2 BASAL
# 1                0        0          0          91   SATO2 RESER MAX
# 2                0        0          0          95               NaN
# 3                0        0          0          95      SATO2 GN 2 L
# 4                0        0          0          99               NaN
# ...            ...      ...        ...         ...               ...
# 224141           0        0          0          98      SATO2 GN 1L
# 224142           0        0          0          96               NaN
# 224143           0        0          0          35       SATO2 GN 4L
# 224144           0        0          0          97       SATO2 GN 1L
# 224145           0        0          0          96       SATO2 GN 3L
#
#         GLU_GLY_ING
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 224141            0
# 224142            0
# 224143            0
# 224144            0
# 224145            0
#
# [224146 rows x 10 columns]

# %%
pd.read_csv('data/COVID_DSL_03.CSV', sep='|', encoding = 'ISO-8859-1')
# Out:
#       IDINGRESO DIA_PPAL  DIA_02  DIA_03  DIA_04   DIA_05 DIA_06 DIA_07  \
# 0           508   B97.29  R68.89  J12.89   J12.9  Z20.828    NaN    NaN
# 1           509   R68.89   J06.9   E11.9  B97.29      NaN    NaN    NaN
# 2           510   B97.29   J12.9  J12.89     NaN      NaN    NaN    NaN
# 3           511    J18.9  R68.89     NaN     NaN      NaN    NaN    NaN
# 4           512   R06.00   B34.2     NaN     NaN      NaN    NaN    NaN
# ...         ...      ...     ...     ...     ...      ...    ...    ...
# 4192       2758    E86.0   E87.1  J12.89   J84.9   R68.89    NaN    NaN
# 4193       2759   J96.90  R68.89     NaN     NaN      NaN    NaN    NaN
# 4194       2760   R06.00  J12.89  B97.29     NaN      NaN    NaN    NaN
# 4195       2761   R68.89  J96.90     NaN     NaN      NaN    NaN    NaN
# 4196       2762    J84.9  J96.90  R68.89     NaN      NaN    NaN    NaN
#
#      DIA_08 DIA_09 DIA_10 DIA_11 DIA_12  PROC_01  PROC_02 PROC_03 PROC_04  \
# 0       NaN    NaN    NaN    NaN    NaN  BW03ZZZ  0BJ0XZZ     NaN     NaN
# 1       NaN    NaN    NaN    NaN    NaN  BW03ZZZ  0BJ0XZZ     NaN     NaN
# 2       NaN    NaN    NaN    NaN    NaN  BW03ZZZ  0BJ0XZZ     NaN     NaN
# 3       NaN    NaN    NaN    NaN    NaN  BW24ZZZ      NaN     NaN     NaN
# 4       NaN    NaN    NaN    NaN    NaN      NaN      NaN     NaN     NaN
# ...     ...    ...    ...    ...    ...      ...      ...     ...     ...
# 4192    NaN    NaN    NaN    NaN    NaN  BW03ZZZ  0BJ0XZZ     NaN     NaN
# 4193    NaN    NaN    NaN    NaN    NaN  BW03ZZZ      NaN     NaN     NaN
# 4194    NaN    NaN    NaN    NaN    NaN  BW03ZZZ      NaN     NaN     NaN
# 4195    NaN    NaN    NaN    NaN    NaN  BW03ZZZ      NaN     NaN     NaN
# 4196    NaN    NaN    NaN    NaN    NaN  BW03ZZZ      NaN     NaN     NaN
#
#      PROC_05
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 4192     NaN
# 4193     NaN
# 4194     NaN
# 4195     NaN
# 4196     NaN
#
# [4197 rows x 18 columns]

# %%
# Import data

for i in range(1,7):
    df_name = 'data1' + str(i)
    file_name = 'COVID_DSL_0' + str(i) + '.CSV'
    file_path = 'data/' + file_name
    print(file_path)
    df_name = pd.read_csv(file_path, sep='|')
# Out:
# data/COVID_DSL_01.CSV
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd3 in position 24: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-8-77cf8fc82bf1> in <module>
#       6     file_path = 'data/' + file_name
#       7     print(file_path)
# ----> 8     df_name = pd.read_csv(file_path, sep='|')
#
# ~/opt/anaconda3/envs/ucml/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/opt/anaconda3/envs/ucml/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# ~/opt/anaconda3/envs/ucml/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1194     def read(self, nrows=None):
#    1195         nrows = _validate_integer("nrows", nrows)
# -> 1196         ret = self._engine.read(nrows)
#    1197
#    1198         # May alter columns / col_dict
#
# ~/opt/anaconda3/envs/ucml/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2153     def read(self, nrows=None):
#    2154         try:
# -> 2155             data = self._reader.read(nrows)
#    2156         except StopIteration:
#    2157             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd3 in position 24: invalid continuation byte
